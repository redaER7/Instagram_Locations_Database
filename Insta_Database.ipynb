# %%
import pandas as pd

# %% [markdown]
# ## Instagram Process Automation
# ---

# %% [markdown]
# ## Reading database of 10 users
# ### Who checked recently in Dubai Mall

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#     Unnamed: 0       Profile name  \
# 0            0          lara_lepp
# 1            1         kimflood13
# 2            2       farahhakimie
# 3            3          lara_lepp
# 4            4         kimflood13
# 5            5       farahhakimie
# 6            6         safa_dubai
# 7            7      miss_nafurana
# 8            8          eebruu___
# 9            9  nehaadhvikmahajan
# 10          10     mary_antonelli
# 11          11           jorgcham
# 12          12  perfume_onlin_uae
#
#                                         Profile Title  \
# 0   LARA LEPP on Instagram: “@ladureeuae 😋 @marish...
# 1   Kim Flood on Instagram: “Sunday’s💕❤️💋 #dubai #...
# 2   Instagram photo by F A R A H • May 16, 2021 at...
# 3   LARA LEPP on Instagram: “@ladureeuae 😋 @marish...
# 4   Kim Flood on Instagram: “Sunday’s💕❤️💋 #dubai #...
# 5   Instagram photo by F A R A H • May 16, 2021 at...
# 6   Safa/صفا on Instagram: “How cute is this co or...
# ...
